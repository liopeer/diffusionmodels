# %%
import sys
sys.path.append("../..")
import matplotlib.pyplot as plt
import torch

from diffusion_models.utils.datasets import LumbarSpineDataset

# %%
ref = torch.randn((1,2,3))

# %%
ds = LumbarSpineDataset()

sample = ds[64][0]

# %%
sample.shape
# Out:
# torch.Size([1, 128, 128])

# %%
ref.permute(1,2,0).size() == (1,2,3)
# Out:
# False

# %%
plt.imshow(sample.permute(2,1,0))
plt.colorbar()

# %%
x = torch.randn((128,128,128))

# %%
sample.shape
# Out:
# torch.Size([1, 128, 128])

# %%
torch.rot90(sample, dims=[0,1]).shape
# Out:
# torch.Size([128, 1, 128])
